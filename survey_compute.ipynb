# %% [markdown]
# <a href="https://colab.research.google.com/github/anapitalai/APEC-API/blob/main/survey_compute.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
import sys
sys.path.append("/content/drive/MyDrive/traverse_auto")
# Out:
# Mounted at /content/drive

# %%
import traverse as t

# %%
t.df[['angle_dd','bearing_dd','shifted_bearing']]
# Out:
#      angle_dd  bearing_dd  shifted_bearing
# 0  122.667778  192.766944              NaN
# 1   91.478333  104.245278       192.766944
# 2  121.408611    0.000000         0.000000
# 3  116.286944    0.000000         0.000000
# 4   88.158333    0.000000         0.000000

# %%
t.new_bear(t.tups[1])
# Out:
# 104.24527777777779

# %%
t.df['bearing_dd']
# Out:
# 0    192.766944
# 1    104.245278
# 2      0.000000
# 3      0.000000
# 4      0.000000
# Name: bearing_dd, dtype: float64

# %%
t.shifted_df
# Out:
#    shifted_bearing    angle_dd
# 0              NaN  122.667778
# 1       192.766944   91.478333
# 2       104.245278  121.408611
# 3         0.000000  116.286944
# 4         0.000000   88.158333

# %%
t.df["shifted_bearing"]=t.df['bearing_dd'].shift(1)
t.shifted_df=t.df[['shifted_bearing','angle_dd']]
t.shifted_df
# Out:
#    shifted_bearing    angle_dd
# 0              NaN  122.667778
# 1       192.766944   91.478333
# 2       104.245278  121.408611
# 3         0.000000  116.286944
# 4         0.000000   88.158333
